# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from scipy.optimize import curve_fit

import sys
import os
sys.path.insert(0, os.path.abspath('../model'))

import Pacejka52 as pa52
import fiala as fi
import Brush as br
import TMeasy as tm
import Dugoff as du
import Pacejka52_glSA as pa52gl
import Pacejka52_Sv_Sh_0 as pa52_0

i=1000
Sx = np.linspace(-1,1,i)
Sy = np.linspace(0,0.3,i)

Fz0 = 3114
IA = 0

#Fz Bereich + Anzahl der Schritte
iter = 10
Fz = np.linspace(1500,5000,iter)

# %%
#lateral

#MFsimpel
Fy_params_init = [-9,1.6,1.5,-24]

fig,ax = plt.subplots(4, figsize = [10,20])
plt.figure(5)
#D Parameter
D_pa52_0 = np.zeros(len(Fz))
D_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,B,C,D,E):
        return pa52_0.Pacejka5_lat_pa(Sy,Fz[i],B,C,D,E)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    D_pa52_0[i] = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[1] / Fz[i]
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    D_pa5[i] = abs(Fy_params[2])

    
    Fy_fit = func_Fy(Sy, *Fy_params)
    plt.plot(Sy,y_data)
    plt.plot(Sy,Fy_fit, 'r--' ) 
    plt.xlim(0,0.3)
    plt.xlabel('Schräglaufwinkel [rad]')
    plt.ylabel('Fy [N]')


#Plotting:
ax[0].plot(Fz,D_pa52_0, label = 'Pacejka52')
ax[0].plot(Fz,D_pa5, 'r--', label = 'Pacejka5')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('D Parameter')
ax[0].set_title('D Parameter')
ax[0].set_xlim(1500,5000)
   
#B Parameter
B_pa52_0 = np.zeros(len(Fz))
B_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,B,C,D,E):
        return pa52_0.Pacejka5_lat_pa(Sy,Fz[i],B,C,D,E)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    B_pa52_0[i] = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[2] 
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    B_pa5[i] = Fy_params[0]


#Plotting:
ax[1].plot(Fz,B_pa52_0, label = 'Pacejka52')
ax[1].plot(Fz,B_pa5, 'r--', label = 'Pacejka5')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('B Parameter')
ax[1].set_title('B Parameter')
ax[1].set_xlim(1500,5000)

#C Parameter
C_pa52_0 = np.zeros(len(Fz))
C_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,B,C,D,E):
        return pa52_0.Pacejka5_lat_pa(Sy,Fz[i],B,C,D,E)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    C_pa52_0[i] = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[3] #/ Fz[i]
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    C_pa5[i] = Fy_params[1]


#Plotting:
ax[2].plot(Fz,C_pa52_0, label = 'Pacejka52')
ax[2].plot(Fz,C_pa5, 'r--', label = 'Pacejka5')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('C Parameter')
ax[2].set_title('C Parameter')
ax[2].set_xlim(1500,5000)

#E Parameter
E_pa52_0 = np.zeros(len(Fz))
E_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,B,C,D,E):
        return pa52_0.Pacejka5_lat_pa(Sy,Fz[i],B,C,D,E)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    E_pa52_0[i] = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[4] 
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    E_pa5[i] = Fy_params[3]


#Plotting:
ax[3].plot(Fz,E_pa52_0, label = 'Pacejka52')
ax[3].plot(Fz,E_pa5, 'r--', label = 'Pacejka5')
ax[3].legend()
ax[3].set_xlabel('Fz [N]')
ax[3].set_ylabel('E Parameter')
ax[3].set_title('E Parameter')
ax[3].set_xlim(1500,5000)
# Out:
# (1500.0, 5000.0)

# %%
#longituginal

#MFsimpel
Fx_params_init = [17,2,9000,0.62]

fig,ax = plt.subplots(4, figsize = [10,20])
plt.figure(5)
#D Parameter
D_pa52_0 = np.zeros(len(Fz))
D_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,B,C,D,E):
        return pa52_0.Pacejka5_long_pa(Sx,Fz[i],B,C,D,E)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    D_pa52_0[i] = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[1] / Fz[i]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    D_pa5[i] = abs(Fx_params[2])

    
    Fx_fit = func_Fx(Sx, *Fx_params)
    plt.plot(Sx,x_data)
    plt.plot(Sx,Fx_fit, 'r--' ) 
    plt.xlim(0,1)
    plt.ylim(0,8000)
    plt.xlabel('Schlupf [%]')
    plt.ylabel('Fx [N]')


#Plotting:
ax[0].plot(Fz,D_pa52_0, label = 'Pacejka52')
ax[0].plot(Fz,D_pa5, 'r--', label = 'Pacejka5')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('D Parameter')
ax[0].set_title('D Parameter')
ax[0].set_xlim(1500,5000)
   
#B Parameter
B_pa52_0 = np.zeros(len(Fz))
B_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,B,C,D,E):
        return pa52_0.Pacejka5_long_pa(Sx,Fz[i],B,C,D,E)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    B_pa52_0[i] = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[2] 
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    B_pa5[i] = Fx_params[0]


#Plotting:
ax[1].plot(Fz,B_pa52_0, label = 'Pacejka52')
ax[1].plot(Fz,B_pa5, 'r--', label = 'Pacejka5')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('B Parameter')
ax[1].set_title('B Parameter')
ax[1].set_xlim(1500,5000)

#C Parameter
C_pa52_0 = np.zeros(len(Fz))
C_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,B,C,D,E):
        return pa52_0.Pacejka5_long_pa(Sx,Fz[i],B,C,D,E)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    C_pa52_0[i] = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[3] #/ Fz[i]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    C_pa5[i] = Fx_params[1]


#Plotting:
ax[2].plot(Fz,C_pa52_0, label = 'Pacejka52')
ax[2].plot(Fz,C_pa5, 'r--', label = 'Pacejka5')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('C Parameter')
ax[2].set_title('C Parameter')
ax[2].set_xlim(1500,5000)

#E Parameter
E_pa52_0 = np.zeros(len(Fz))
E_pa5 = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,B,C,D,E):
        return pa52_0.Pacejka5_long_pa(Sx,Fz[i],B,C,D,E)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    E_pa52_0[i] = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[5]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    E_pa5[i] = Fx_params[3]


#Plotting:
ax[3].plot(Fz,E_pa52_0, label = 'Pacejka52')
ax[3].plot(Fz,E_pa5, 'r--', label = 'Pacejka5')
ax[3].legend()
ax[3].set_xlabel('Fz [N]')
ax[3].set_ylabel('E Parameter')
ax[3].set_title('E Parameter')
ax[3].set_xlim(1500,5000)
# Out:
# (1500.0, 5000.0)

# %%
def diff_func(y,SL): #y = Funktion die abgleitet werden soll, Sl = linspace
    dx = SL[1]-SL[0]
    dydx = np.gradient(y, dx)
    return dydx

E_long_grad = diff_func(E_pa5,Fz)[1]

def E_linear(E_long_grad,E_pa5,Fz_test):
    return   E_pa5[0] + E_long_grad * (Fz_test-1500)
# Out:
# 0.81937533076429
# 1035.1997976878613
# 0.8193753307642903
# 6.462106615285796e-05

# %%
##########  
#TMeasy #
##########

#lateral
Fz = np.linspace(1500,5000,20)
Fy_params_init = [103490.7691515877, 7681.6857595551, 6238.0217868243, 0.1, 0.3, -225]

fig,ax = plt.subplots(6, figsize = [10,30])
plt.figure(5)
#D Parameter
D_pa52_0 = np.zeros(len(Fz))
DFY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    DFY[i] = abs(Fy_params[0])

    
    Fy_fit = func_Fy(Sy, *Fy_params)
    plt.plot(Sy,y_data)
    plt.plot(Sy,Fy_fit, 'r--' ) 
    plt.xlim(0,0.3)
    plt.ylim(0,8000)
    plt.xlabel('Schräglaufwinkel [rad]')
    plt.ylabel('Fy [N]')

#Plotting:
ax[0].plot(Fz,DFY, 'r--', label = 'TMeasy')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('DFY Parameter')
ax[0].set_title('DFY Parameter')
ax[0].set_xlim(1500,5000)
   

FMY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    FMY[i] = abs(Fy_params[1])

#Plotting:
ax[1].plot(Fz,FMY, 'r--', label = 'TMeasy')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('FMY Parameter')
ax[1].set_title('FMY Parameter')
ax[1].set_xlim(1500,5000)

FSY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    FSY[i] = abs(Fy_params[2])

#Plotting:
ax[2].plot(Fz,FSY, 'r--', label = 'TMeasy')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('FSY Parameter')
ax[2].set_title('FSY Parameter')
ax[2].set_xlim(1500,5000)

SMY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    SMY[i] = abs(Fy_params[3])

#Plotting:
ax[3].plot(Fz,SMY, 'r--', label = 'TMeasy')
ax[3].legend()
ax[3].set_xlabel('Fz [N]')
ax[3].set_ylabel('SMY Parameter')
ax[3].set_title('SMY Parameter')
ax[3].set_xlim(1500,5000)

SSY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    SSY[i] = abs(Fy_params[4])

#Plotting:
ax[4].plot(Fz,SSY, 'r--', label = 'TMeasy')
ax[4].legend()
ax[4].set_xlabel('Fz [N]')
ax[4].set_ylabel('SSY Parameter')
ax[4].set_title('SSY Parameter')
ax[4].set_xlim(1500,5000)

SMX = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy,DFY, FMY, FSY, SMY, SSY,SMX):
        return tm.calcFY(Sx, Sy, DFY, FMY, FSY, SMY, SSY,SMX)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
        
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    SMX[i] = abs(Fy_params[5])

#Plotting:
ax[5].plot(Fz,SMX, 'r--', label = 'TMeasy')
ax[5].legend()
ax[5].set_xlabel('Fz [N]')
ax[5].set_ylabel('SMX Parameter')
ax[5].set_title('SMX Parameter')
ax[5].set_xlim(1500,5000)
# Out:
# (1500.0, 5000.0)

# %%
##########  
#TMeasy #
##########

#lateral
Fz = np.linspace(1500,5000,20)
Sx = np.linspace(0,0.25,100)
Sy = np.linspace(0,0.3,100)
Sxx = np.linspace(0,1,100)
Fx_params_init = [2.48428391e+05, 7.45113790e+03, 5.28849020e+03, 6.06693945e-02, 2.61320192e-01,  9.09203532e-01]

fig,ax = plt.subplots(6, figsize = [10,30])
plt.figure(5)
#D Parameter
D_pa52_0 = np.zeros(len(Fz))
DFX = np.zeros(len(Fz))
for i in range(1,len(Fz)):
   
    def func_Fx(Sx,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    DFX[i] = abs(Fx_params[0])

    x_data_fit = pa52_0.Pacejka52_long(Fz[i],Sxx,IA,Fz0)[0]
    Fx_fit = tm.calcFx( Sxx, Sy, *Fx_params)
    plt.plot(Sxx,x_data_fit)
    plt.plot(Sxx,Fx_fit, 'r--' ) 
    plt.xlim(0,1)
    plt.xlabel('Schräglaufwinkel [rad]')
    plt.ylabel('Fx [N]')

#Plotting:
ax[0].plot(Fz,DFX, 'r--', label = 'TMeasy')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('DFX Parameter')
ax[0].set_title('DFX Parameter')
ax[0].set_xlim(1500,5000)
   
FMX = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sy,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
        
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    FMX[i] = abs(Fx_params[1])

#Plotting:
ax[1].plot(Fz,FMX, 'r--', label = 'TMeasy')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('FMX Parameter')
ax[1].set_title('FMX Parameter')
ax[1].set_xlim(1500,5000)

FSX = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
        
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    FSX[i] = abs(Fx_params[2])

#Plotting:
ax[2].plot(Fz,FSX, 'r--', label = 'TMeasy')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('FSX Parameter')
ax[2].set_title('FSX Parameter')
ax[2].set_xlim(1500,5000)

SMX = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
        
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    SMX[i] = abs(Fx_params[3])

#Plotting:
ax[3].plot(Fz,SMX, 'r--', label = 'TMeasy')
ax[3].legend()
ax[3].set_xlabel('Fz [N]')
ax[3].set_ylabel('SMX Parameter')
ax[3].set_title('SMX Parameter')
ax[3].set_xlim(1500,5000)

SSX = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
        
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    SSX[i] = abs(Fx_params[4])

#Plotting:
ax[4].plot(Fz,SSX, 'r--', label = 'TMeasy')
ax[4].legend()
ax[4].set_xlabel('Fz [N]')
ax[4].set_ylabel('SSX Parameter')
ax[4].set_title('SSX Parameter')
ax[4].set_xlim(1500,5000)

SMY = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx,DFX, FMX, FSX, SMX,SSX, SMY):
        return tm.calcFx( Sx, Sy, DFX, FMX, FSX, SMX,SSX, SMY)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
        
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    SMY[i] = abs(Fx_params[5])

#Plotting:
ax[5].plot(Fz,SMY, 'r--', label = 'TMeasy')
ax[5].legend()
ax[5].set_xlabel('Fz [N]')
ax[5].set_ylabel('SMY Parameter')
ax[5].set_title('SMY Parameter')
ax[5].set_xlim(1500,5000)
# Out:
# (1500.0, 5000.0)

# %%
###############################################################
#Brush
###############################################################

#lateral

#MFsimpel
Fy_params_init = [1.5, 1.10061960e+05, 0.04]

fig,ax = plt.subplots(3, figsize = [10,15])
plt.figure(5)
#D Parameter
D_pa52_0 = np.zeros(len(Fz))
mu = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy, mu, kt, lam):
        return br.brush_lat(Sy ,Fz[i],mu,kt, lam)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    mu[i] = abs(Fy_params[0])

    
    Fy_fit = func_Fy(Sy, *Fy_params)
    plt.plot(Sy,y_data)
    plt.plot(Sy,Fy_fit, 'r--' ) 
    plt.xlim(0,0.3)
    plt.xlabel('Schräglaufwinkel [rad]')
    plt.ylabel('Fy [N]')


#Plotting:
ax[0].plot(Fz,mu, 'r--', label = 'Brush')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('mu Parameter')
ax[0].set_title('mu Parameter')
ax[0].set_xlim(1500,5000)
   
kt = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy, mu, kt, lam):
        return br.brush_lat(Sy ,Fz[i],mu,kt, lam)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    kt[i] = abs(Fy_params[1])

#Plotting:
ax[1].plot(Fz,kt, 'r--', label = 'Brush')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('kt Parameter')
ax[1].set_title('kt Parameter')
ax[1].set_xlim(1500,5000)

lam = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fy(Sy, mu, kt, lam):
        return br.brush_lat(Sy ,Fz[i],mu,kt, lam)

    y_data = pa52_0.Pacejka52_lat(Fz[i],Sy,IA,Fz0)[0]
    
    Fy_params, _ = curve_fit(func_Fy, Sy, y_data, Fy_params_init)
    lam[i] = abs(Fy_params[2])

#Plotting:
ax[2].plot(Fz,lam, 'r--', label = 'Brush')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('lam Parameter')
ax[2].set_title('lam Parameter')
ax[2].set_xlim(1500,5000)
# Out:
# c:\Users\bener\OneDrive\Dokumente\07_Bachelorarbeit\Git\SA_Tire_model\model\Brush.py:107: RuntimeWarning: divide by zero encountered in double_scalars
#   lc[i] = mu * Fz / (lt * kt * Sy[i]) - lam
# c:\Users\bener\OneDrive\Dokumente\07_Bachelorarbeit\Git\SA_Tire_model\model\Brush.py:108: RuntimeWarning: invalid value encountered in double_scalars
#   Fx[i] = kt * Sy[i] * (lc[i]) * (lam + lc[i] / 2) + mu * Fz * (1 - lc[i] / lt)
# (1500.0, 5000.0)

# %%
###############################################################
#Brush
###############################################################

#longitudinal
Sx = np.linspace(0,0.15,1000)
Sxx = np.linspace(0,1,1000)
#MFsimpel
Fx_params_init = [0.8, 36000, 0.04]

fig,ax = plt.subplots(3, figsize = [10,15])
plt.figure(5)
#D Parameter
mu = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx, mu, kt, lam):
        return br.brush_long(Sx ,Fz[i],mu,kt, lam)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    mu[i] = abs(Fx_params[0])

    
    Fxx_fit = br.brush_long(Sxx ,Fz[i], *Fx_params)
    xx_data = pa52_0.Pacejka52_long(Fz[i],Sxx,IA,Fz0)[0]
    plt.plot(Sxx,xx_data)
    plt.plot(Sxx,Fxx_fit, 'r--' ) 
    plt.xlim(0,1)
    plt.xlabel('Schlupf [%]')
    plt.ylabel('Fx [N]')


#Plotting:
ax[0].plot(Fz,mu, 'r--', label = 'Brush')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('mu Parameter')
ax[0].set_title('mu Parameter')
ax[0].set_xlim(1500,5000)
   
kt = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sx, mu, kt, lam):
        return br.brush_long(Sx ,Fz[i],mu,kt, lam)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    kt[i] = abs(Fx_params[1])

#Plotting:
ax[1].plot(Fz,kt, 'r--', label = 'Brush')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('kt Parameter')
ax[1].set_title('kt Parameter')
ax[1].set_xlim(1500,5000)

lam = np.zeros(len(Fz))
for i in range(0,len(Fz)):
   
    def func_Fx(Sy, mu, kt, lam):
        return br.brush_long(Sx ,Fz[i],mu,kt, lam)

    x_data = pa52_0.Pacejka52_long(Fz[i],Sx,IA,Fz0)[0]
    
    Fx_params, _ = curve_fit(func_Fx, Sx, x_data, Fx_params_init)
    lam[i] = abs(Fx_params[2])

#Plotting:
ax[2].plot(Fz,lam, 'r--', label = 'Brush')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('lam Parameter')
ax[2].set_title('lam Parameter')
ax[2].set_xlim(1500,5000)


#fig.savefig('test.svg', format='svg')
# Out:
# (1500.0, 5000.0)

# %%
######
#Fiala
######

#Händisch fitting mit Fiala_fit.ipynb

#Fz = 1500
Fx_params_1500 = [-1.00684611e+05, -2.3288, -1.829]
Fy_params_1500 = [-4.32768914e+04, -2.30, -1.649]

#Fz = 2500
Fx_params_3000 = [-2.00684611e+05, -2.3288, -1.629]
Fy_params_3000 = [-9.02768914e+04, -2.30, -1.549]

#Fz = 5000
Fx_params_5000 = [-3.40684611e+05, -2.10288, -1.4529]
Fy_params_5000 = [-1.52768914e+05, -2.50, -1.249]

Fx_1500 = fi.fiala_long(Sx,1500,*Fx_params_1500)
Fx_3000 = fi.fiala_long(Sx,3000,*Fx_params_3000)
Fx_5000 = fi.fiala_long(Sx,5000,*Fx_params_5000)

Fy_1500 = fi.fiala_lat(Sy,1500,*Fy_params_1500)
Fy_3000 = fi.fiala_lat(Sy,3000,*Fy_params_3000)
Fy_5000 = fi.fiala_lat(Sy,5000,*Fy_params_5000)

Fz = [1500, 3000, 5000]
plt.figure(1)
for j in range(len(Fz)):
    Fx = pa52_0.Pacejka52_long(Fz[j],Sx,IA,Fz0)[0]
    plt.plot(Sx,Fx, 'y')

plt.plot(Sx,Fx_1500, label = 'Fz = 1500 N')
plt.plot(Sx,Fx_3000, label = 'Fz = 3000 N')
plt.plot(Sx,Fx_5000, label = 'Fz = 5000 N')
plt.legend()
plt.xlabel('Schlupf [%]')
plt.ylabel('Fx [N]')

plt.figure(2)
for j in range(len(Fz)):
    Fy = pa52_0.Pacejka52_lat(Fz[j],Sy,IA,Fz0)[0]
    plt.plot(Sy,Fy, 'y')

plt.plot(Sy,Fy_1500, label = 'Fz = 1500 N')
plt.plot(Sy,Fy_3000, label = 'Fz = 3000 N')
plt.plot(Sy,Fy_5000, label = 'Fz = 5000 N')
plt.legend()
plt.xlabel('Schräglaufwinkel [rad]')
plt.ylabel('Fy [N]')

fig,ax = plt.subplots(3, figsize = [10,15])
#D Parameter
C_long = [Fx_params_1500[0], Fx_params_3000[0], Fx_params_5000[0]]

#Plotting:
ax[0].plot(Fz,C_long, 'r--', label = 'Brush')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('C_long Parameter')
ax[0].set_title('C_long Parameter')
ax[0].set_xlim(1500,5000)
   
mu1 = [Fx_params_1500[1], Fx_params_3000[1], Fx_params_5000[1]]

#Plotting:
ax[1].plot(Fz,mu1, 'r--', label = 'Brush')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('mu1 Parameter')
ax[1].set_title('mu1 Parameter')
ax[1].set_xlim(1500,5000)
   
mu2 = [Fx_params_1500[2], Fx_params_3000[2], Fx_params_5000[2]]

#Plotting:
ax[2].plot(Fz,mu2, 'r--', label = 'Brush')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('mu2 Parameter')
ax[2].set_title('mu2 Parameter')
ax[2].set_xlim(1500,5000)

fig,ax = plt.subplots(3, figsize = [10,15])
#D Parameter
C_long = [Fy_params_1500[0], Fy_params_3000[0], Fx_params_5000[0]]

#Plotting:
ax[0].plot(Fz,C_long, 'r--', label = 'Fiala')
ax[0].legend()
ax[0].set_xlabel('Fz [N]')
ax[0].set_ylabel('C_lat Parameter')
ax[0].set_title('C_lat Parameter')
ax[0].set_xlim(1500,5000)
   
mu1 = [Fy_params_1500[1], Fy_params_3000[1], Fy_params_5000[1]]

#Plotting:
ax[1].plot(Fz,mu1, 'r--', label = 'Fiala')
ax[1].legend()
ax[1].set_xlabel('Fz [N]')
ax[1].set_ylabel('mu1 Parameter')
ax[1].set_title('mu1 Parameter')
ax[1].set_xlim(1500,5000)
   
mu2 = [Fy_params_1500[2], Fy_params_3000[2], Fy_params_5000[2]]

#Plotting:
ax[2].plot(Fz,mu2, 'r--', label = 'Fiala')
ax[2].legend()
ax[2].set_xlabel('Fz [N]')
ax[2].set_ylabel('mu2 Parameter')
ax[2].set_title('mu2 Parameter')
ax[2].set_xlim(1500,5000)
# Out:
# (1500.0, 5000.0)

# %%
######
#Fiala
######

#Händisch fitting mit Fiala_fit.ipynb

#Fz = 1500
Fx_params_1500 = [-1.00684611e+05, -2.3288, -1.829]
Fy_params_1500 = [-4.32768914e+04, -2.30, -1.649]

#Fz = 2500
Fx_params_3000 = [-2.00684611e+05, -2.3288, -1.629]
Fy_params_3000 = [-9.02768914e+04, -2.30, -1.549]

#Fz = 5000
Fx_params_5000 = [-3.40684611e+05, -2.10288, -1.4529]
Fy_params_5000 = [-1.52768914e+05, -2.50, -1.249]

Fx_1500 = fi.fiala_long(Sx,1500,*Fx_params_1500)
Fx_3000 = fi.fiala_long(Sx,3000,*Fx_params_3000)
Fx_5000 = fi.fiala_long(Sx,5000,*Fx_params_5000)

Fy_1500 = fi.fiala_lat(Sy,1500,*Fy_params_1500)
Fy_3000 = fi.fiala_lat(Sy,3000,*Fy_params_3000)
Fy_5000 = fi.fiala_lat(Sy,5000,*Fy_params_5000)

Fz = [1500, 3000, 5000]
plt.figure(1)

Fx = pa52_0.Pacejka52_long(1500,Sx,IA,Fz0)[0]
plt.plot(Sx,Fx, 'r--', label = 'Pacejka 5.2 Indy')
Fx = pa52_0.Pacejka52_long(3000,Sx,IA,Fz0)[0]
plt.plot(Sx,Fx, 'r--')
Fx = pa52_0.Pacejka52_long(5000,Sx,IA,Fz0)[0]
plt.plot(Sx,Fx, 'r--')

plt.plot(Sx,Fx_1500, label = 'Fz = 1500 N')
plt.plot(Sx,Fx_3000, label = 'Fz = 3000 N')
plt.plot(Sx,Fx_5000, label = 'Fz = 5000 N')
#plt.legend()
plt.xlabel('Schlupf [%]')
plt.ylabel('Fx [N]')
leg = plt.legend()

# Hinzufügen einer zusätzlichen Beschriftung zur Legende
extra_label = "Zusätzliche Beschriftung"
for text in leg.get_texts():
    if text.get_text() == "Linie 2":
        text.set_text(f"Linie 2 ({extra_label})")

plt.savefig('fiala_long.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#####
#Dugoff
#####
Sy = np.linspace(-0.3,0.3,len(Sx))

#Händisch fitting mit Fiala_fit.ipynb

#Fz = 1500
Fx_params_1500 = [ 9.60848636e+04, -8.30029214e-01,  1.35387231e+00]
Fy_params_1500 = [2.91029382e-01, 2.31921206e+03, 1.45895147e-01]

#Fz = 3000
Fx_params_3000 =[ 1.16724596e+05, -5.22466167e+00 , 1.30360646e+00]
Fy_params_3000 = [1.94120979e-01,  4.07519670e+03,  1.42305583e-01]

#Fz = 5000
Fx_params_5000 = [ 1.99921140e+05, -3.01660109e+00,  1.17191007e+00]
Fy_params_5000 =[1.27681485e+00, 7.52703245e+03, 1.30255055e-01]

Fx_1500 = du.dugoff_long(Sx,Sy,1500,*Fx_params_1500)
Fx_3000 = du.dugoff_long(Sx,Sy,3000,*Fx_params_3000)
Fx_5000 = du.dugoff_long(Sx,Sy,5000,*Fx_params_5000)

Fy_15001 = du.dugoff_lat(Sx,Sy,1500,*Fy_params_1500)
Fy_15001 = Fy_15001[499:999]
Fy_15001_spax = np.zeros(len(Fy_15001))
for i in range(0,len(Fy_15001)):
    Fy_1500_spax[i] = -Fy_15001[499 - i]
Fy_1500 = np. concatenate((Fy_1500_spax, Fy_15001))

Fy_30001 = du.dugoff_lat(Sx,Sy,3000,*Fy_params_3000)
Fy_30001 = Fy_30001[499:999]
Fy_30001_spax = np.zeros(len(Fy_30001))
for i in range(0,len(Fy_15001)):
    Fy_3000_spax[i] = -Fy_30001[499 - i]
Fy_3000 = np. concatenate((Fy_3000_spax, Fy_30001))

Fy_50001 = du.dugoff_lat(Sx,Sy,5000,*Fy_params_5000)
Fy_50001 = Fy_50001[499:999]
Fy_50001_spax = np.zeros(len(Fy_15001))
for i in range(0,len(Fy_15001)):
    Fy_5000_spax[i] = -Fy_50001[499 - i]
Fy_5000 = np. concatenate((Fy_5000_spax, Fy_50001))


fig,ax = plt.subplots(1,2, figsize = [13,5])

Fx = pa52_0.Pacejka52_long(1500,Sx,IA,Fz0)[0]
ax[0].plot(Sx,Fx, 'r--', label = 'Pacejka 5.2 Indy')
Fx = pa52_0.Pacejka52_long(3000,Sx,IA,Fz0)[0]
ax[0].plot(Sx,Fx, 'r--')
Fx = pa52_0.Pacejka52_long(5000,Sx,IA,Fz0)[0]
ax[0].plot(Sx,Fx, 'r--')

ax[0].plot(Sx,Fx_1500, label = 'Fz = 1500 N')
ax[0].plot(Sx,Fx_3000, label = 'Fz = 3000 N')
ax[0].plot(Sx,Fx_5000, label = 'Fz = 5000 N')
ax[0]. set_xlabel('Schlupf [%]')
ax[0].set_ylabel('Fx [N]')
ax[0].legend()

S_plt = np.linspace(-15,15,len(Sx))
Sy = np.linspace(-0.3,0.3,len(Sx))
Fy = pa52_0.Pacejka52_lat(1500,Sy,IA,Fz0)[0]
ax[1].plot(S_plt,Fy, 'r--', label = 'Pacejka 5.2 Indy')
Fy = pa52_0.Pacejka52_lat(3000,Sy,IA,Fz0)[0]
ax[1].plot(S_plt,Fy, 'r--')
Fy = pa52_0.Pacejka52_lat(5000,Sy,IA,Fz0)[0]
ax[1].plot(S_plt,Fy, 'r--')

ax[1].plot(S_plt,Fy_1500, label = 'Fz = 1500 N')
ax[1].plot(S_plt,Fy_3000, label = 'Fz = 3000 N')
ax[1].plot(S_plt,Fy_5000, label = 'Fz = 5000 N')
ax[1]. set_xlabel('Schräglaufwinkel [°]')
ax[1].set_ylabel('Fy [N]')
ax[1].legend()

fig.savefig('dugoff.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
